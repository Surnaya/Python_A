# %%
from sympy import *
from sympy.plotting import plot
import math
import random
import matplotlib.pyplot as plt
from sympy.calculus.util import minimum, maximum, Interval

# %%
x = symbols ('x')
f = -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %%
plot(f, (x, -150, 150))

# %%
roots = solve(f, x)
roots
